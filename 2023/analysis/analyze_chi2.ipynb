# %% [markdown]
# Code to get $chi^2$ results to Claudio
#
# Created by Linnea on October 11, 2023

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from pathlib import Path
from collections import defaultdict
import h5py
import keras_core as keras
import tensorflow_io as tfio

import sys
sys.path.append('../')
import preprocess.preprocess
import utils
import jax
import jax.numpy as jnp

# %load_ext autoreload
# %autoreload 2
# Out:
# 2023-10-31 19:45:39.110683: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-31 19:45:40.097869: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-31 19:45:40.118715: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 19:47:15.207928: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend

# %%
# Load metadata for this interval
def index_mcmc_runs():
    """Make a list of combinations for which we want to run MCMC."""
    experiments = ['AMS02_H-PRL2021']
    dfs = []
    for experiment_name in experiments:
        filename = f'../../data/2023/{experiment_name}_heliosphere.dat'
        df = utils.index_experiment_files(filename) 
        df['experiment_name'] = experiment_name
        df['filename_heliosphere'] = filename
        dfs.append(df)
    df = pd.concat(dfs, axis=0, ignore_index=0)
    return df

# Select experiment parameters
df = index_mcmc_runs()  # List of all ~200 experiments.
data = df.iloc[0]

# %%
# Load parameters
polarity = 'neg'
path = '/home/linneamw/sadow_koastore/personal/linneamw/research/gcr/data/2023_07_01'
f_original = f'{path}/{polarity}/model_collection_1AU_90deg_0deg.h5'

# 8 input parameters for the NN: alpha, cmf, vspoles, cpa, pwr1par, pwr2par, pwr1perr, and pwr2perr.
# features = ['alpha', 'cmf', 'cpa', 'pwr1par', 'pwr1perr', 'pwr2par', 'pwr2perr', 'vspoles']
with h5py.File(f_original, 'r') as h5:
    print(h5.keys())

    info = h5['info']
    model = h5['model']

    print(info.keys())
    print(model.keys())

    # Get relevant parameters
    alpha = h5['model/alpha'][:]
    cmf = h5['model/cmf'][:]
    cpa = h5['model/cpa'][:]
    pwr1par = h5['model/pwr1par'][:]
    pwr1perr = h5['model/pwr1perr'][:]
    pwr2par = h5['model/pwr2par'][:]
    pwr2perr = h5['model/pwr2perr'][:]
    vspoles = h5['model/vspoles'][:]
    imodel = h5['model/imodel'][:]
    rigidity = h5['info/rigidity'][:]
# Out:
# <KeysViewHDF5 ['info', 'model']>
# <KeysViewHDF5 ['LIS', 'rigidity']>
# <KeysViewHDF5 ['alpha', 'cmf', 'cpa', 'flux', 'imodel', 'ipar', 'pwr1par', 'pwr1perr', 'pwr2par', 'pwr2perr', 'quality', 'vseq', 'vspoles']>

# %%
# Find parameters associated with index 1889802
index = 1889802

# Load parameters for NN: ['alpha', 'cmf', 'cpa', 'pwr1par', 'pwr1perr', 'pwr2par', 'pwr2perr', 'vspoles']
parameters = (alpha[index], cmf[index], cpa[index], pwr1par[index], pwr1perr[index], pwr2par[index], pwr2perr[index], vspoles[index])

print(f'imodel: {imodel[index]}')
print(f'(alpha, cmf, cpa, pwr1par, pwr1perr, pwr2par, pwr2perr, vspoles): {parameters}')
# Out:
# imodel: 1889802
# (alpha, cmf, cpa, pwr1par, pwr1perr, pwr2par, pwr2perr, vspoles): (55.0, 4.5, 390.0, 1.3, 1.0, 2.3, 0.4, 600.0)

# %%
model_version = 'v3.0'
data_path = f'../../data/oct2022/{data.experiment_name}/{data.experiment_name}_{data.interval}.dat'  # This data is the same.
model_path = f'../../models/model_{model_version}_{data.polarity}.keras'
penalty = 1e6

print(f'model_path: {model_path}')
print(f'data_path: {data_path}')

# Load trained NN model that maps 7 parameters to predicted flux at RIGIDITY_VALS.
model = keras.models.load_model(model_path)
model.run_eagerly = True # Settable attribute (in elegy). Required to be true for ppmodel.

# Load observation data from Claudio
bins, observed, uncertainty = utils.load_data_ams(data_path)
bin_midpoints = (bins[:-1] * bins[1:]) ** 0.5  # Geometric mean seemed to work better in exp.

# Transform parameters
parameters_transformed = utils.transform_input(jnp.array(parameters))

# Predict flux
xs = parameters_transformed.reshape((1,-1)) # Reshape to (,8) for keras.
yhat = model(xs)
yhat = yhat.numpy()[0] # Convert to float32
yhat = utils.untransform_output(yhat.reshape((1,-1))).reshape(-1) # Undo scaling and minmax.
log_yhat = np.log(yhat)
# Out:
# model_path: ../../models/model_v3.0_neg.keras
# data_path: ../../data/oct2022/AMS02_H-PRL2021/AMS02_H-PRL2021_20110520-20110610.dat

# %% [markdown]
# ## Way 1: interpolated chi^2, log-log interpolation at geometric mean of midpoint

# %%
# Interpolate to get predicted flux at midpoint of bin points.
yhat_interp = jnp.interp(bin_midpoints, utils.RIGIDITY_VALS, log_yhat)

# Compute log prob
chi2_interp = (((yhat_interp - observed)/uncertainty)**2)
residual_interp = (yhat_interp - observed)/uncertainty

print(f'chi2_interp: {chi2_interp}')
# Out:
# chi2_interp: [1.1355219e+03 1.8906440e+03 2.8022266e+03 3.7665627e+03 4.6596187e+03
#  5.4470601e+03 6.0993247e+03 6.6741899e+03 7.1358501e+03 7.5271826e+03
#  7.7285498e+03 7.8565991e+03 7.8701948e+03 7.9878838e+03 7.9579014e+03
#  7.7289805e+03 7.4963135e+03 7.2905845e+03 7.0844023e+03 6.7085312e+03
#  6.3673843e+03 6.1410981e+03 5.7708857e+03 5.2328916e+03 4.2016177e+03
#  3.0766404e+03 3.2941108e+03 2.4305336e+04 4.6356000e+05 7.0275215e+06]

# %% [markdown]
# ## Way 2: integrated chi^2, using Claudio's code to calculate the integral

# %%
class ModelChi2:
    def __init__(self, mLogR, mLogF):
        self.mLogR = mLogR
        self.mLogF = mLogF

    def interpolate_model(self, x):
        lnx = np.log(x)
        ig = self.find_grid_point(lnx)

        print(f"Interpolating model for x: {x:.3f}, which has self.mLogR[ig]: {self.mLogR[ig]:.3f} and self.mLogR[ig+1]: {self.mLogR[ig+1]:.3f}, and self.mLogF[ig]: {self.mLogF[ig]:.3f} and self.mLogF[ig+1]: {self.mLogF[ig+1]:.3f}")

        s = (lnx - self.mLogR[ig]) / (self.mLogR[ig+1] - self.mLogR[ig])
        result = np.exp((1 - s) * self.mLogF[ig] + s * self.mLogF[ig+1])

        return result

    def compute_integral(self, x1, x2):
        lnx1 = np.log(x1)
        lnx2 = np.log(x2)
        ig1 = self.find_grid_point(lnx1)
        ig2 = self.find_grid_point(lnx2)

        # Compute integral from a to b at grid point ig
        def integral(a, b, ig):
            assert ig < len(self.mLogR), f"ArithmeticError: ig:{ig}> len(self.mLogR):{len(self.mLogR)}"
            assert ig < len(self.mLogF), f"ArithmeticError: ig:{ig}> len(self.mLogF):{len(self.mLogF)}"

            print(f"Computing integral from {a:.3f} to {b:.3f}, which has self.mLogR[ig]: {self.mLogR[ig]:.3f} and self.mLogR[ig+1]: {self.mLogR[ig+1]:.3f}, and self.mLogF[ig]: {self.mLogF[ig]:.3f} and self.mLogF[ig+1]: {self.mLogF[ig+1]:.3f}")

            M = (self.mLogF[ig+1] - self.mLogF[ig]) / (self.mLogR[ig+1] - self.mLogR[ig])
            N = np.exp(self.mLogF[ig] - M * self.mLogR[ig])
            Mp1 = M + 1
            N_mp1 = N / Mp1
            mp1b_mp1a = np.exp(Mp1 * b) - np.exp(Mp1 * a)
            result = N_mp1 * mp1b_mp1a

            print(f'M: {M:.3f}, N: {N:.3f}, Mp1: {Mp1:.3f}, N_mp1: {N_mp1:.3f}, mp1b_mp1a: {mp1b_mp1a:.3f}')
            print(f'Computed integral: {result:.3f}')

            return result

        # Compute integral from lnx1 to min(lnx2, self.mLogR[ig1+1]) at grid point ig1
        assert ig1+1 < len(self.mLogR), f"ArithmeticError: ig1+1:{ig1+1}> len(self.mLogR):{len(self.mLogR)}"
        I = integral(lnx1, min(lnx2, self.mLogR[ig1+1]), ig1)

        # For each grid point between ig1+1 and ig2, compute integral from R[ig] to min(lnx2, R[ig+1]) at grid point ig
        for ig in range(ig1+1, ig2+1):
            assert ig+1 < len(self.mLogR), f"ArithmeticError: ig+1:{ig+1}> len(self.mLogR):{len(self.mLogR)}"
            I += integral(self.mLogR[ig], min(lnx2, self.mLogR[ig+1]), ig)
        
        # If lnx2 > R[ig2+1], compute integral from R[ig2+1] to lnx2 at grid point ig2
        if lnx2 > self.mLogR[ig2+1]:
            assert ig2+1 < len(self.mLogR), f"ArithmeticError: ig2+1:{ig2+1}> len(self.mLogR):{len(self.mLogR)}"
            I += integral(self.mLogR[ig2+1], lnx2, ig2)

        return I

    # find grid point ig such that R[ig] <= x <= R[ig+1]
    def find_grid_point(self, value): # Checked: this works correctly. 
        result = np.searchsorted(self.mLogR, value, side="left")-1
        
        if result >= len(self.mLogR)-1:
            result = len(self.mLogR)-2

        print(f'Finding grid_point for the value: {value:.3f}, self.mLogR[result]: {self.mLogR[result]:.3f} and self.mLogR[result+1]: {self.mLogR[result+1]:.3f}')

        return result

# Usage:
# mLogR = your mLogR data as a numpy array, in logspace
# mLogF = your mLogF data as a numpy array, in logspace
# model = ModelChi2(mLogR, mLogF)
# result = model.compute_integral(x1, x2)

# %%
# Get log_rigidity and log_yhat
log_rigidity = np.log(utils.RIGIDITY_VALS)

print(f'bins: {len(bins)}\n{bins}\n\n')
print(f'log_yhat: {len(log_yhat)}\n{log_yhat}')
print(f'log_rigidity: {len(log_rigidity)}\n{log_rigidity}')

# Initialize model
model = ModelChi2(log_rigidity, log_yhat)
yhat_integral = []
yhat_interp = []

# Compute integral for each bin
for x1, x2 in zip(bins[:-1], bins[1:]):
    print(f'\nCurrent x1: {x1}, x2: {x2}')
    integral = model.compute_integral(x1, x2) / (x2 - x1)

    print(f'Integral: {integral:.3f}')
    yhat_integral.append(integral)

# Compute interpolated value for each bin
for x in bin_midpoints:
    print(f'\nx: {x}')
    interpolated = model.interpolate_model(x)

    print(f'Interpolated: {interpolated:.3f}')
    yhat_interp.append(interpolated)

print(f'yhat_integral: {len(yhat_integral)}\n{yhat_integral}')
print(f'yhat_interp: {len(yhat_interp)}\n{yhat_interp}')
# Out:
# bins: 31
# [  1.     1.16   1.33   1.51   1.71   1.92   2.15   2.4    2.67   2.97
#    3.29   3.64   4.02   4.43   4.88   5.37   5.9    6.47   7.09   7.76
#    8.48   9.26  10.1   11.    13.    16.6   22.8   33.5   48.5   69.7
#  100.  ]
#
#
# log_yhat: 32
# [ 3.589842    3.6240537   3.6784282   3.7757766   3.9370165   4.115487
#   4.3290825   4.594681    4.88857     5.189218    5.537966    5.875779
#   6.1928697   6.489793    6.7057624   6.8199687   6.814575    6.6836143
#   6.423785    6.036938    5.5648704   4.954528    4.268897    3.4731126
#   2.568606    1.6393415   0.63703626 -0.40959284 -1.5269916  -2.6721764
#  -3.8564389  -5.032763  ]
# log_rigidity: 32
# [-1.60943791 -1.59862765 -1.57700712 -1.54457635 -1.49052507 -1.42566349
#  -1.34999171 -1.25269936 -1.1445968  -1.02568395 -0.88515058 -0.73380696
#  -0.57165308 -0.38787868 -0.19329403  0.01210089  0.23911632  0.47694201
#   0.72557796  0.99583442  1.26609089  1.56877813  1.87146537  2.19577313
#   2.54170141  2.88762969  3.25517848  3.63353753  4.0335171   4.44430693
#   4.86590702  5.29831737]
#
# Current x1: 1.0, x2: 1.16
# Finding grid_point for the value: 0.000, self.mLogR[result]: -0.193 and self.mLogR[result+1]: 0.012
# Finding grid_point for the value: 0.148, self.mLogR[result]: 0.012 and self.mLogR[result+1]: 0.239
# Computing integral from 0.000 to 0.012, which has self.mLogR[ig]: -0.193 and self.mLogR[ig+1]: 0.012, and self.mLogF[ig]: 6.706 and self.mLogF[ig+1]: 6.820
# M: 0.556, N: 909.814, Mp1: 1.556, N_mp1: 584.701, mp1b_mp1a: 0.019
# Computed integral: 11.114
# Computing integral from 0.012 to 0.148, which has self.mLogR[ig]: 0.012 and self.mLogR[ig+1]: 0.239, and self.mLogF[ig]: 6.820 and self.mLogF[ig+1]: 6.815
# M: -0.024, N: 916.220, Mp1: 0.976, N_mp1: 938.517, mp1b_mp1a: 0.144
# Computed integral: 135.178
# Integral: 914.323
#
# Current x1: 1.16, x2: 1.33
# Finding grid_point for the value: 0.148, self.mLogR[result]: 0.012 and self.mLogR[result+1]: 0.239
# Finding grid_point for the value: 0.285, self.mLogR[result]: 0.239 and self.mLogR[result+1]: 0.477
# Computing integral from 0.148 to 0.239, which has self.mLogR[ig]: 0.012 and self.mLogR[ig+1]: 0.239, and self.mLogF[ig]: 6.820 and self.mLogF[ig+1]: 6.815
# M: -0.024, N: 916.220, Mp1: 0.976, N_mp1: 938.517, mp1b_mp1a: 0.107
# Computed integral: 100.435
# Computing integral from 0.239 to 0.285, which has self.mLogR[ig]: 0.239 and self.mLogR[ig+1]: 0.477, and self.mLogF[ig]: 6.815 and self.mLogF[ig+1]: 6.684
# M: -0.551, N: 1039.242, Mp1: 0.449, N_mp1: 2312.815, mp1b_mp1a: 0.023
# Computed integral: 53.856
# Integral: 907.590
#
# Current x1: 1.33, x2: 1.51
# Finding grid_point for the value: 0.285, self.mLogR[result]: 0.239 and self.mLogR[result+1]: 0.477
# Finding grid_point for the value: 0.412, self.mLogR[result]: 0.239 and self.mLogR[result+1]: 0.477
# Computing integral from 0.285 to 0.412, which has self.mLogR[ig]: 0.239 and self.mLogR[ig+1]: 0.477, and self.mLogF[ig]: 6.815 and self.mLogF[ig+1]: 6.684
# M: -0.551, N: 1039.242, Mp1: 0.449, N_mp1: 2312.815, mp1b_mp1a: 0.067
# Computed integral: 154.305
# Integral: 857.248
#
# Current x1: 1.51, x2: 1.71
# Finding grid_point for the value: 0.412, self.mLogR[result]: 0.239 and self.mLogR[result+1]: 0.477
# Finding grid_point for the value: 0.536, self.mLogR[result]: 0.477 and self.mLogR[result+1]: 0.726
# Computing integral from 0.412 to 0.477, which has self.mLogR[ig]: 0.239 and self.mLogR[ig+1]: 0.477, and self.mLogF[ig]: 6.815 and self.mLogF[ig+1]: 6.684
# M: -0.551, N: 1039.242, Mp1: 0.449, N_mp1: 2312.815, mp1b_mp1a: 0.036
# Computed integral: 82.276
# Computing integral from 0.477 to 0.536, which has self.mLogR[ig]: 0.477 and self.mLogR[ig+1]: 0.726, and self.mLogF[ig]: 6.684 and self.mLogF[ig+1]: 6.424
# M: -1.045, N: 1315.573, Mp1: -0.045, N_mp1: -29223.246, mp1b_mp1a: -0.003
# Computed integral: 76.577
# Integral: 794.265
#
# Current x1: 1.71, x2: 1.92
# Finding grid_point for the value: 0.536, self.mLogR[result]: 0.477 and self.mLogR[result+1]: 0.726
# Finding grid_point for the value: 0.652, self.mLogR[result]: 0.477 and self.mLogR[result+1]: 0.726
# Computing integral from 0.536 to 0.652, which has self.mLogR[ig]: 0.477 and self.mLogR[ig+1]: 0.726, and self.mLogF[ig]: 6.684 and self.mLogF[ig+1]: 6.424
# M: -1.045, N: 1315.573, Mp1: -0.045, N_mp1: -29223.246, mp1b_mp1a: -0.005
# Computed integral: 148.362
# Integral: 706.484
#
# Current x1: 1.92, x2: 2.15
# Finding grid_point for the value: 0.652, self.mLogR[result]: 0.477 and self.mLogR[result+1]: 0.726
# Finding grid_point for the value: 0.765, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Computing integral from 0.652 to 0.726, which has self.mLogR[ig]: 0.477 and self.mLogR[ig+1]: 0.726, and self.mLogF[ig]: 6.684 and self.mLogF[ig+1]: 6.424
# M: -1.045, N: 1315.573, Mp1: -0.045, N_mp1: -29223.246, mp1b_mp1a: -0.003
# Computed integral: 93.426
# Computing integral from 0.726 to 0.765, which has self.mLogR[ig]: 0.726 and self.mLogR[ig+1]: 0.996, and self.mLogF[ig]: 6.424 and self.mLogF[ig+1]: 6.037
# M: -1.431, N: 1741.292, Mp1: -0.431, N_mp1: -4036.308, mp1b_mp1a: -0.012
# Computed integral: 50.357
# Integral: 625.145
#
# Current x1: 2.15, x2: 2.4
# Finding grid_point for the value: 0.765, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Finding grid_point for the value: 0.875, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Computing integral from 0.765 to 0.875, which has self.mLogR[ig]: 0.726 and self.mLogR[ig+1]: 0.996, and self.mLogF[ig]: 6.424 and self.mLogF[ig+1]: 6.037
# M: -1.431, N: 1741.292, Mp1: -0.431, N_mp1: -4036.308, mp1b_mp1a: -0.033
# Computed integral: 134.458
# Integral: 537.833
#
# Current x1: 2.4, x2: 2.67
# Finding grid_point for the value: 0.875, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Finding grid_point for the value: 0.982, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Computing integral from 0.875 to 0.982, which has self.mLogR[ig]: 0.726 and self.mLogR[ig+1]: 0.996, and self.mLogF[ig]: 6.424 and self.mLogF[ig+1]: 6.037
# M: -1.431, N: 1741.292, Mp1: -0.431, N_mp1: -4036.308, mp1b_mp1a: -0.031
# Computed integral: 124.364
# Integral: 460.607
#
# Current x1: 2.67, x2: 2.97
# Finding grid_point for the value: 0.982, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Finding grid_point for the value: 1.089, self.mLogR[result]: 0.996 and self.mLogR[result+1]: 1.266
# Computing integral from 0.982 to 0.996, which has self.mLogR[ig]: 0.726 and self.mLogR[ig+1]: 0.996, and self.mLogF[ig]: 6.424 and self.mLogF[ig+1]: 6.037
# M: -1.431, N: 1741.292, Mp1: -0.431, N_mp1: -4036.308, mp1b_mp1a: -0.004
# Computed integral: 15.634
# Computing integral from 0.996 to 1.089, which has self.mLogR[ig]: 0.996 and self.mLogR[ig+1]: 1.266, and self.mLogF[ig]: 6.037 and self.mLogF[ig+1]: 5.565
# M: -1.747, N: 2383.683, Mp1: -0.747, N_mp1: -3192.119, mp1b_mp1a: -0.032
# Computed integral: 101.521
# Integral: 390.516
#
# Current x1: 2.97, x2: 3.29
# Finding grid_point for the value: 1.089, self.mLogR[result]: 0.996 and self.mLogR[result+1]: 1.266
# Finding grid_point for the value: 1.191, self.mLogR[result]: 0.996 and self.mLogR[result+1]: 1.266
# Computing integral from 1.089 to 1.191, which has self.mLogR[ig]: 0.996 and self.mLogR[ig+1]: 1.266, and self.mLogF[ig]: 6.037 and self.mLogF[ig+1]: 5.565
# M: -1.747, N: 2383.683, Mp1: -0.747, N_mp1: -3192.119, mp1b_mp1a: -0.033
# Computed integral: 104.165
# Integral: 325.514
#
# Current x1: 3.29, x2: 3.64
# Finding grid_point for the value: 1.191, self.mLogR[result]: 0.996 and self.mLogR[result+1]: 1.266
# Finding grid_point for the value: 1.292, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Computing integral from 1.191 to 1.266, which has self.mLogR[ig]: 0.996 and self.mLogR[ig+1]: 1.266, and self.mLogF[ig]: 6.037 and self.mLogF[ig+1]: 5.565
# M: -1.747, N: 2383.683, Mp1: -0.747, N_mp1: -3192.119, mp1b_mp1a: -0.022
# Computed integral: 71.637
# Computing integral from 1.266 to 1.292, which has self.mLogR[ig]: 1.266 and self.mLogR[ig+1]: 1.569, and self.mLogF[ig]: 5.565 and self.mLogF[ig+1]: 4.955
# M: -2.016, N: 3353.744, Mp1: -1.016, N_mp1: -3299.587, mp1b_mp1a: -0.007
# Computed integral: 23.666
# Integral: 272.294
#
# Current x1: 3.64, x2: 4.02
# Finding grid_point for the value: 1.292, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Finding grid_point for the value: 1.391, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Computing integral from 1.292 to 1.391, which has self.mLogR[ig]: 1.266 and self.mLogR[ig+1]: 1.569, and self.mLogF[ig]: 5.565 and self.mLogF[ig+1]: 4.955
# M: -2.016, N: 3353.744, Mp1: -1.016, N_mp1: -3299.587, mp1b_mp1a: -0.026
# Computed integral: 85.198
# Integral: 224.205
#
# Current x1: 4.02, x2: 4.43
# Finding grid_point for the value: 1.391, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Finding grid_point for the value: 1.488, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Computing integral from 1.391 to 1.488, which has self.mLogR[ig]: 1.266 and self.mLogR[ig+1]: 1.569, and self.mLogF[ig]: 5.565 and self.mLogF[ig+1]: 4.955
# M: -2.016, N: 3353.744, Mp1: -1.016, N_mp1: -3299.587, mp1b_mp1a: -0.023
# Computed integral: 75.410
# Integral: 183.926
#
# Current x1: 4.43, x2: 4.88
# Finding grid_point for the value: 1.488, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Finding grid_point for the value: 1.585, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Computing integral from 1.488 to 1.569, which has self.mLogR[ig]: 1.266 and self.mLogR[ig+1]: 1.569, and self.mLogF[ig]: 5.565 and self.mLogF[ig+1]: 4.955
# M: -2.016, N: 3353.744, Mp1: -1.016, N_mp1: -3299.587, mp1b_mp1a: -0.017
# Computed integral: 57.021
# Computing integral from 1.569 to 1.585, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# M: -2.265, N: 4954.440, Mp1: -1.265, N_mp1: -3916.101, mp1b_mp1a: -0.003
# Computed integral: 11.029
# Integral: 151.222
#
# Current x1: 4.88, x2: 5.37
# Finding grid_point for the value: 1.585, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Finding grid_point for the value: 1.681, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Computing integral from 1.585 to 1.681, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# M: -2.265, N: 4954.440, Mp1: -1.265, N_mp1: -3916.101, mp1b_mp1a: -0.015
# Computed integral: 60.097
# Integral: 122.648
#
# Current x1: 5.37, x2: 5.9
# Finding grid_point for the value: 1.681, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Finding grid_point for the value: 1.775, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Computing integral from 1.681 to 1.775, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# M: -2.265, N: 4954.440, Mp1: -1.265, N_mp1: -3916.101, mp1b_mp1a: -0.013
# Computed integral: 52.429
# Integral: 98.923
#
# Current x1: 5.9, x2: 6.47
# Finding grid_point for the value: 1.775, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Finding grid_point for the value: 1.867, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Computing integral from 1.775 to 1.867, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# M: -2.265, N: 4954.440, Mp1: -1.265, N_mp1: -3916.101, mp1b_mp1a: -0.012
# Computed integral: 45.657
# Integral: 80.100
#
# Current x1: 6.47, x2: 7.09
# Finding grid_point for the value: 1.867, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Finding grid_point for the value: 1.959, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Computing integral from 1.867 to 1.871, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# M: -2.265, N: 4954.440, Mp1: -1.265, N_mp1: -3916.101, mp1b_mp1a: -0.001
# Computed integral: 1.997
# Computing integral from 1.871 to 1.959, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# M: -2.454, N: 7052.150, Mp1: -1.454, N_mp1: -4850.859, mp1b_mp1a: -0.008
# Computed integral: 38.028
# Integral: 64.555
#
# Current x1: 7.09, x2: 7.76
# Finding grid_point for the value: 1.959, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Finding grid_point for the value: 2.049, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Computing integral from 1.959 to 2.049, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# M: -2.454, N: 7052.150, Mp1: -1.454, N_mp1: -4850.859, mp1b_mp1a: -0.007
# Computed integral: 34.605
# Integral: 51.649
#
# Current x1: 7.76, x2: 8.48
# Finding grid_point for the value: 2.049, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Finding grid_point for the value: 2.138, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Computing integral from 2.049 to 2.138, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# M: -2.454, N: 7052.150, Mp1: -1.454, N_mp1: -4850.859, mp1b_mp1a: -0.006
# Computed integral: 29.854
# Integral: 41.463
#
# Current x1: 8.48, x2: 9.26
# Finding grid_point for the value: 2.138, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Finding grid_point for the value: 2.226, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Computing integral from 2.138 to 2.196, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# M: -2.454, N: 7052.150, Mp1: -1.454, N_mp1: -4850.859, mp1b_mp1a: -0.004
# Computed integral: 17.552
# Computing integral from 2.196 to 2.226, which has self.mLogR[ig]: 2.196 and self.mLogR[ig+1]: 2.542, and self.mLogF[ig]: 3.473 and self.mLogF[ig+1]: 2.569
# M: -2.615, N: 10041.196, Mp1: -1.615, N_mp1: -6218.525, mp1b_mp1a: -0.001
# Computed integral: 8.465
# Integral: 33.355
#
# Current x1: 9.26, x2: 10.1
# Finding grid_point for the value: 2.226, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Finding grid_point for the value: 2.313, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Computing integral from 2.226 to 2.313, which has self.mLogR[ig]: 2.196 and self.mLogR[ig+1]: 2.542, and self.mLogF[ig]: 3.473 and self.mLogF[ig+1]: 2.569
# M: -2.615, N: 10041.196, Mp1: -1.615, N_mp1: -6218.525, mp1b_mp1a: -0.004
# Computed integral: 22.365
# Integral: 26.625
#
# Current x1: 10.1, x2: 11.0
# Finding grid_point for the value: 2.313, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Finding grid_point for the value: 2.398, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Computing integral from 2.313 to 2.398, which has self.mLogR[ig]: 2.196 and self.mLogR[ig+1]: 2.542, and self.mLogF[ig]: 3.473 and self.mLogF[ig+1]: 2.569
# M: -2.615, N: 10041.196, Mp1: -1.615, N_mp1: -6218.525, mp1b_mp1a: -0.003
# Computed integral: 19.132
# Integral: 21.257
#
# Current x1: 11.0, x2: 13.0
# Finding grid_point for the value: 2.398, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Finding grid_point for the value: 2.565, self.mLogR[result]: 2.542 and self.mLogR[result+1]: 2.888
# Computing integral from 2.398 to 2.542, which has self.mLogR[ig]: 2.196 and self.mLogR[ig+1]: 2.542, and self.mLogF[ig]: 3.473 and self.mLogF[ig+1]: 2.569
# M: -2.615, N: 10041.196, Mp1: -1.615, N_mp1: -6218.525, mp1b_mp1a: -0.004
# Computed integral: 26.826
# Computing integral from 2.542 to 2.565, which has self.mLogR[ig]: 2.542 and self.mLogR[ig+1]: 2.888, and self.mLogF[ig]: 2.569 and self.mLogF[ig+1]: 1.639
# M: -2.686, N: 12044.441, Mp1: -1.686, N_mp1: -7142.559, mp1b_mp1a: -0.001
# Computed integral: 3.778
# Integral: 15.302
#
# Current x1: 13.0, x2: 16.6
# Finding grid_point for the value: 2.565, self.mLogR[result]: 2.542 and self.mLogR[result+1]: 2.888
# Finding grid_point for the value: 2.809, self.mLogR[result]: 2.542 and self.mLogR[result+1]: 2.888
# Computing integral from 2.565 to 2.809, which has self.mLogR[ig]: 2.542 and self.mLogR[ig+1]: 2.888, and self.mLogF[ig]: 2.569 and self.mLogF[ig+1]: 1.639
# M: -2.686, N: 12044.441, Mp1: -1.686, N_mp1: -7142.559, mp1b_mp1a: -0.004
# Computed integral: 31.923
# Integral: 8.868
#
# Current x1: 16.6, x2: 22.8
# Finding grid_point for the value: 2.809, self.mLogR[result]: 2.542 and self.mLogR[result+1]: 2.888
# Finding grid_point for the value: 3.127, self.mLogR[result]: 2.888 and self.mLogR[result+1]: 3.255
# Computing integral from 2.809 to 2.888, which has self.mLogR[ig]: 2.542 and self.mLogR[ig+1]: 2.888, and self.mLogF[ig]: 2.569 and self.mLogF[ig+1]: 1.639
# M: -2.686, N: 12044.441, Mp1: -1.686, N_mp1: -7142.559, mp1b_mp1a: -0.001
# Computed integral: 7.733
# Computing integral from 2.888 to 3.127, which has self.mLogR[ig]: 2.888 and self.mLogR[ig+1]: 3.255, and self.mLogF[ig]: 1.639 and self.mLogF[ig+1]: 0.637
# M: -2.727, N: 13546.796, Mp1: -1.727, N_mp1: -7844.124, mp1b_mp1a: -0.002
# Computed integral: 18.117
# Integral: 4.169
#
# Current x1: 22.8, x2: 33.5
# Finding grid_point for the value: 3.127, self.mLogR[result]: 2.888 and self.mLogR[result+1]: 3.255
# Finding grid_point for the value: 3.512, self.mLogR[result]: 3.255 and self.mLogR[result+1]: 3.634
# Computing integral from 3.127 to 3.255, which has self.mLogR[ig]: 2.888 and self.mLogR[ig+1]: 3.255, and self.mLogF[ig]: 1.639 and self.mLogF[ig+1]: 0.637
# M: -2.727, N: 13546.796, Mp1: -1.727, N_mp1: -7844.124, mp1b_mp1a: -0.001
# Computed integral: 7.048
# Computing integral from 3.255 to 3.512, which has self.mLogR[ig]: 3.255 and self.mLogR[ig+1]: 3.634, and self.mLogF[ig]: 0.637 and self.mLogF[ig+1]: -0.410
# M: -2.766, N: 15392.204, Mp1: -1.766, N_mp1: -8714.711, mp1b_mp1a: -0.001
# Computed integral: 10.107
# Integral: 1.603
#
# Current x1: 33.5, x2: 48.5
# Finding grid_point for the value: 3.512, self.mLogR[result]: 3.255 and self.mLogR[result+1]: 3.634
# Finding grid_point for the value: 3.882, self.mLogR[result]: 3.634 and self.mLogR[result+1]: 4.034
# Computing integral from 3.512 to 3.634, which has self.mLogR[ig]: 3.255 and self.mLogR[ig+1]: 3.634, and self.mLogF[ig]: 0.637 and self.mLogF[ig+1]: -0.410
# M: -2.766, N: 15392.204, Mp1: -1.766, N_mp1: -8714.711, mp1b_mp1a: -0.000
# Computed integral: 3.421
# Computing integral from 3.634 to 3.882, which has self.mLogR[ig]: 3.634 and self.mLogR[ig+1]: 4.034, and self.mLogF[ig]: -0.410 and self.mLogF[ig+1]: -1.527
# M: -2.794, N: 17003.955, Mp1: -1.794, N_mp1: -9480.141, mp1b_mp1a: -0.001
# Computed integral: 5.031
# Integral: 0.563
#
# Current x1: 48.5, x2: 69.7
# Finding grid_point for the value: 3.882, self.mLogR[result]: 3.634 and self.mLogR[result+1]: 4.034
# Finding grid_point for the value: 4.244, self.mLogR[result]: 4.034 and self.mLogR[result+1]: 4.444
# Computing integral from 3.882 to 4.034, which has self.mLogR[ig]: 3.634 and self.mLogR[ig+1]: 4.034, and self.mLogF[ig]: -0.410 and self.mLogF[ig+1]: -1.527
# M: -2.794, N: 17003.955, Mp1: -1.794, N_mp1: -9480.141, mp1b_mp1a: -0.000
# Computed integral: 2.142
# Computing integral from 4.034 to 4.244, which has self.mLogR[ig]: 4.034 and self.mLogR[ig+1]: 4.444, and self.mLogF[ig]: -1.527 and self.mLogF[ig+1]: -2.672
# M: -2.788, N: 16605.659, Mp1: -1.788, N_mp1: -9288.512, mp1b_mp1a: -0.000
# Computed integral: 2.153
# Integral: 0.203
#
# Current x1: 69.7, x2: 100.0
# Finding grid_point for the value: 4.244, self.mLogR[result]: 4.034 and self.mLogR[result+1]: 4.444
# Finding grid_point for the value: 4.605, self.mLogR[result]: 4.444 and self.mLogR[result+1]: 4.866
# Computing integral from 4.244 to 4.444, which has self.mLogR[ig]: 4.034 and self.mLogR[ig+1]: 4.444, and self.mLogF[ig]: -1.527 and self.mLogF[ig+1]: -2.672
# M: -2.788, N: 16605.659, Mp1: -1.788, N_mp1: -9288.512, mp1b_mp1a: -0.000
# Computed integral: 1.415
# Computing integral from 4.444 to 4.605, which has self.mLogR[ig]: 4.444 and self.mLogR[ig+1]: 4.866, and self.mLogF[ig]: -2.672 and self.mLogF[ig+1]: -3.856
# M: -2.809, N: 18246.963, Mp1: -1.809, N_mp1: -10086.928, mp1b_mp1a: -0.000
# Computed integral: 0.821
# Integral: 0.074
#
# x: 1.0770329614269007
# Finding grid_point for the value: 0.074, self.mLogR[result]: 0.012 and self.mLogR[result+1]: 0.239
# Interpolating model for x: 1.077, which has self.mLogR[ig]: 0.012 and self.mLogR[ig+1]: 0.239, and self.mLogF[ig]: 6.820 and self.mLogF[ig+1]: 6.815
# Interpolated: 914.606
#
# x: 1.242095004417939
# Finding grid_point for the value: 0.217, self.mLogR[result]: 0.012 and self.mLogR[result+1]: 0.239
# Interpolating model for x: 1.242, which has self.mLogR[ig]: 0.012 and self.mLogR[ig+1]: 0.239, and self.mLogF[ig]: 6.820 and self.mLogF[ig+1]: 6.815
# Interpolated: 911.513
#
# x: 1.4171450172794597
# Finding grid_point for the value: 0.349, self.mLogR[result]: 0.239 and self.mLogR[result+1]: 0.477
# Interpolating model for x: 1.417, which has self.mLogR[ig]: 0.239 and self.mLogR[ig+1]: 0.477, and self.mLogF[ig]: 6.815 and self.mLogF[ig+1]: 6.684
# Interpolated: 857.707
#
# x: 1.6068914089010495
# Finding grid_point for the value: 0.474, self.mLogR[result]: 0.239 and self.mLogR[result+1]: 0.477
# Interpolating model for x: 1.607, which has self.mLogR[ig]: 0.239 and self.mLogR[ig+1]: 0.477, and self.mLogF[ig]: 6.815 and self.mLogF[ig+1]: 6.684
# Interpolated: 800.365
#
# x: 1.81196026446498
# Finding grid_point for the value: 0.594, self.mLogR[result]: 0.477 and self.mLogR[result+1]: 0.726
# Interpolating model for x: 1.812, which has self.mLogR[ig]: 0.477 and self.mLogR[ig+1]: 0.726, and self.mLogF[ig]: 6.684 and self.mLogF[ig+1]: 6.424
# Interpolated: 706.879
#
# x: 2.031748015872047
# Finding grid_point for the value: 0.709, self.mLogR[result]: 0.477 and self.mLogR[result+1]: 0.726
# Interpolating model for x: 2.032, which has self.mLogR[ig]: 0.477 and self.mLogR[ig+1]: 0.726, and self.mLogF[ig]: 6.684 and self.mLogF[ig+1]: 6.424
# Interpolated: 627.170
#
# x: 2.2715633383201093
# Finding grid_point for the value: 0.820, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Interpolating model for x: 2.272, which has self.mLogR[ig]: 0.726 and self.mLogR[ig+1]: 0.996, and self.mLogF[ig]: 6.424 and self.mLogF[ig+1]: 6.037
# Interpolated: 538.054
#
# x: 2.5314027731674784
# Finding grid_point for the value: 0.929, self.mLogR[result]: 0.726 and self.mLogR[result+1]: 0.996
# Interpolating model for x: 2.531, which has self.mLogR[ig]: 0.726 and self.mLogR[ig+1]: 0.996, and self.mLogF[ig]: 6.424 and self.mLogF[ig+1]: 6.037
# Interpolated: 460.784
#
# x: 2.816007812489163
# Finding grid_point for the value: 1.035, self.mLogR[result]: 0.996 and self.mLogR[result+1]: 1.266
# Interpolating model for x: 2.816, which has self.mLogR[ig]: 0.996 and self.mLogR[ig+1]: 1.266, and self.mLogF[ig]: 6.037 and self.mLogF[ig+1]: 5.565
# Interpolated: 390.710
#
# x: 3.125907868124075
# Finding grid_point for the value: 1.140, self.mLogR[result]: 0.996 and self.mLogR[result+1]: 1.266
# Interpolating model for x: 3.126, which has self.mLogR[ig]: 0.996 and self.mLogR[ig+1]: 1.266, and self.mLogF[ig]: 6.037 and self.mLogF[ig+1]: 5.565
# Interpolated: 325.577
#
# x: 3.460577986406317
# Finding grid_point for the value: 1.241, self.mLogR[result]: 0.996 and self.mLogR[result+1]: 1.266
# Interpolating model for x: 3.461, which has self.mLogR[ig]: 0.996 and self.mLogR[ig+1]: 1.266, and self.mLogF[ig]: 6.037 and self.mLogF[ig+1]: 5.565
# Interpolated: 272.581
#
# x: 3.8252843031597012
# Finding grid_point for the value: 1.342, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Interpolating model for x: 3.825, which has self.mLogR[ig]: 1.266 and self.mLogR[ig+1]: 1.569, and self.mLogF[ig]: 5.565 and self.mLogF[ig+1]: 4.955
# Interpolated: 224.202
#
# x: 4.220023696615932
# Finding grid_point for the value: 1.440, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Interpolating model for x: 4.220, which has self.mLogR[ig]: 1.266 and self.mLogR[ig+1]: 1.569, and self.mLogF[ig]: 5.565 and self.mLogF[ig+1]: 4.955
# Interpolated: 183.923
#
# x: 4.649559118884284
# Finding grid_point for the value: 1.537, self.mLogR[result]: 1.266 and self.mLogR[result+1]: 1.569
# Interpolating model for x: 4.650, which has self.mLogR[ig]: 1.266 and self.mLogR[ig+1]: 1.569, and self.mLogF[ig]: 5.565 and self.mLogF[ig+1]: 4.955
# Interpolated: 151.270
#
# x: 5.119140552866272
# Finding grid_point for the value: 1.633, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Interpolating model for x: 5.119, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# Interpolated: 122.620
#
# x: 5.628765406374653
# Finding grid_point for the value: 1.728, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Interpolating model for x: 5.629, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# Interpolated: 98.901
#
# x: 6.178430221342635
# Finding grid_point for the value: 1.821, self.mLogR[result]: 1.569 and self.mLogR[result+1]: 1.871
# Interpolating model for x: 6.178, which has self.mLogR[ig]: 1.569 and self.mLogR[ig+1]: 1.871, and self.mLogF[ig]: 4.955 and self.mLogF[ig+1]: 4.269
# Interpolated: 80.083
#
# x: 6.772909271502166
# Finding grid_point for the value: 1.913, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Interpolating model for x: 6.773, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# Interpolated: 64.531
#
# x: 7.417438911106717
# Finding grid_point for the value: 2.004, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Interpolating model for x: 7.417, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# Interpolated: 51.629
#
# x: 8.112015779077355
# Finding grid_point for the value: 2.093, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Interpolating model for x: 8.112, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# Interpolated: 41.448
#
# x: 8.86142200778182
# Finding grid_point for the value: 2.182, self.mLogR[result]: 1.871 and self.mLogR[result+1]: 2.196
# Interpolating model for x: 8.861, which has self.mLogR[ig]: 1.871 and self.mLogR[ig+1]: 2.196, and self.mLogF[ig]: 4.269 and self.mLogF[ig+1]: 3.473
# Interpolated: 33.369
#
# x: 9.670884137450928
# Finding grid_point for the value: 2.269, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Interpolating model for x: 9.671, which has self.mLogR[ig]: 2.196 and self.mLogR[ig+1]: 2.542, and self.mLogF[ig]: 3.473 and self.mLogF[ig+1]: 2.569
# Interpolated: 26.611
#
# x: 10.540398474441087
# Finding grid_point for the value: 2.355, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Interpolating model for x: 10.540, which has self.mLogR[ig]: 2.196 and self.mLogR[ig+1]: 2.542, and self.mLogF[ig]: 3.473 and self.mLogF[ig+1]: 2.569
# Interpolated: 21.247
#
# x: 11.958260743101398
# Finding grid_point for the value: 2.481, self.mLogR[result]: 2.196 and self.mLogR[result+1]: 2.542
# Interpolating model for x: 11.958, which has self.mLogR[ig]: 2.196 and self.mLogR[ig+1]: 2.542, and self.mLogF[ig]: 3.473 and self.mLogF[ig+1]: 2.569
# Interpolated: 15.275
#
# x: 14.690132742763083
# Finding grid_point for the value: 2.687, self.mLogR[result]: 2.542 and self.mLogR[result+1]: 2.888
# Interpolating model for x: 14.690, which has self.mLogR[ig]: 2.542 and self.mLogR[ig+1]: 2.888, and self.mLogF[ig]: 2.569 and self.mLogF[ig+1]: 1.639
# Interpolated: 8.827
#
# x: 19.454562446891476
# Finding grid_point for the value: 2.968, self.mLogR[result]: 2.888 and self.mLogR[result+1]: 3.255
# Interpolating model for x: 19.455, which has self.mLogR[ig]: 2.888 and self.mLogR[ig+1]: 3.255, and self.mLogF[ig]: 1.639 and self.mLogF[ig+1]: 0.637
# Interpolated: 4.137
#
# x: 27.636931812341256
# Finding grid_point for the value: 3.319, self.mLogR[result]: 3.255 and self.mLogR[result+1]: 3.634
# Interpolating model for x: 27.637, which has self.mLogR[ig]: 3.255 and self.mLogR[ig+1]: 3.634, and self.mLogF[ig]: 0.637 and self.mLogF[ig+1]: -0.410
# Interpolated: 1.584
#
# x: 40.308187753854675
# Finding grid_point for the value: 3.697, self.mLogR[result]: 3.634 and self.mLogR[result+1]: 4.034
# Interpolating model for x: 40.308, which has self.mLogR[ig]: 3.634 and self.mLogR[ig+1]: 4.034, and self.mLogF[ig]: -0.410 and self.mLogF[ig+1]: -1.527
# Interpolated: 0.557
#
# x: 58.14163740384338
# Finding grid_point for the value: 4.063, self.mLogR[result]: 4.034 and self.mLogR[result+1]: 4.444
# Interpolating model for x: 58.142, which has self.mLogR[ig]: 4.034 and self.mLogR[ig+1]: 4.444, and self.mLogF[ig]: -1.527 and self.mLogF[ig+1]: -2.672
# Interpolated: 0.200
#
# x: 83.48652585896721
# Finding grid_point for the value: 4.425, self.mLogR[result]: 4.034 and self.mLogR[result+1]: 4.444
# Interpolating model for x: 83.487, which has self.mLogR[ig]: 4.034 and self.mLogR[ig+1]: 4.444, and self.mLogF[ig]: -1.527 and self.mLogF[ig+1]: -2.672
# Interpolated: 0.073
# yhat_integral: 30
# [914.3228699467401, 907.5901298306451, 857.2477014982301, 794.2645180766857, 706.4843108369353, 625.1451504575492, 537.833064420139, 460.6065156167691, 390.5155196793803, 325.51423299071683, 272.2943193875363, 224.2048797446232, 183.92570359243743, 151.22191445778856, 122.64762928669843, 98.92258853143447, 80.09999642269568, 64.55501816731007, 51.64897322526588, 41.46343313917971, 33.355020279900366, 26.6246200863629, 21.25736024954724, 15.30201307618724, 8.867564086000206, 4.169324141231509, 1.6032029724134018, 0.5634067166217105, 0.20257540924291118, 0.07381426836212766]
# yhat_interp: 30
# [914.6057446402531, 911.5125896956499, 857.7070351349666, 800.3653166193071, 706.8785306568097, 627.1699883446569, 538.0537787183661, 460.78406210254815, 390.7104608143063, 325.5770539998474, 272.58124141810504, 224.2018317800887, 183.92331179592202, 151.26974383554278, 122.61953874843465, 98.90066356906982, 80.08295279922211, 64.53125133612646, 51.6294424250555, 41.44829384843087, 33.36900139293258, 26.61118245215735, 21.246991899888258, 15.275023537089636, 8.827029733268137, 4.136910035255331, 1.5841815582766527, 0.5567495062190108, 0.20011678818962056, 0.07298686677915532]

# %%
# Compute log prob for integral
chi2_integral = (((yhat_integral - observed)/uncertainty)**2)
residual_integral = (yhat_integral - observed)/uncertainty

# Compute log prob for interpolation
chi2_interp = (((yhat_interp - observed)/uncertainty)**2)
residual_interp = (yhat_interp - observed)/uncertainty

print(f'chi2_integral: {chi2_integral}')
print(f'chi2_interp: {chi2_interp}')
# Out:
# chi2_integral: [2.01741124 2.44509114 1.4323885  0.22164475 0.05371504 0.63194258
#  0.99959153 2.91828136 6.45423456 6.09950023 9.22666034 5.63385252
#  3.90386468 6.86793821 4.24053465 2.58315052 3.22433777 2.59893809
#  0.74362674 0.20273395 0.25994414 0.11325549 1.09244452 2.65839684
#  5.35112926 8.18279546 9.75248905 8.16145331 5.21564299 4.74068413]
# chi2_interp: [1.98893210e+00 1.90756361e+00 1.36628265e+00 9.36789519e-07
#  3.74221616e-02 1.07970857e+00 1.06634628e+00 3.03066826e+00
#  6.68031351e+00 6.18640974e+00 9.83069947e+00 5.62783494e+00
#  3.89906921e+00 7.02659660e+00 4.15139212e+00 2.51668017e+00
#  3.15327692e+00 2.48968956e+00 6.84761094e-01 1.74053582e-01
#  2.99724554e-01 1.45542669e-01 1.18367987e+00 3.17727627e+00
#  7.25868209e+00 1.21640362e+01 1.63821262e+01 1.41818191e+01
#  1.03189667e+01 8.97056409e+00]

# %% [markdown]
# ## Print final solution

# %%
# For each data bin, print the rigidity (geometric mean + left and right edges); the data value and uncertainty; 
# the model interpolated in the geometric mean and its residual (data - model)/uncertainty; 
# the integral of the model over the bin and its residual; and the cumulative chi2 using the model integral.

for i in range(len(bin_midpoints)):
    print(f'[0{i}] rig = {bin_midpoints[i]:.6f} [{bins[i]:.2f}, {bins[i+1]:.2f}]; data = {observed[i]:.6e}; unc = {uncertainty[i]:.6e}; mod = {yhat_interp[i]:.6e}; res = {residual_interp[i]:+.6e}; mod_int = {yhat_integral[i]:.6e}; res_int = {residual_integral[i]:+.6e}; cum_chi2_interpolated = {np.sum(chi2_interp[:i+1]):.6e}; cum_chi2_integrated = {np.sum(chi2_integral[:i+1]):.6e}')
# Out:
# [00] rig = 1.077033 [1.00, 1.16]; data = 9.542576e+02; unc = 2.811600e+01; mod = 9.146057e+02; res = -1.410295e+00; mod_int = 9.143229e+02; res_int = -1.420356e+00; cum_chi2_interpolated = 1.988932e+00; cum_chi2_integrated = 2.017411e+00
# [01] rig = 1.242095 [1.16, 1.33]; data = 9.411921e+02; unc = 2.148905e+01; mod = 9.115126e+02; res = -1.381146e+00; mod_int = 9.075901e+02; res_int = -1.563679e+00; cum_chi2_interpolated = 3.896496e+00; cum_chi2_integrated = 4.462502e+00
# [02] rig = 1.417145 [1.33, 1.51]; data = 8.769211e+02; unc = 1.643800e+01; mod = 8.577070e+02; res = -1.168881e+00; mod_int = 8.572477e+02; res_int = -1.196824e+00; cum_chi2_interpolated = 5.262778e+00; cum_chi2_integrated = 5.894891e+00
# [03] rig = 1.606891 [1.51, 1.71]; data = 8.003528e+02; unc = 1.293201e+01; mod = 8.003653e+02; res = +9.678789e-04; mod_int = 7.942645e+02; res_int = -4.707916e-01; cum_chi2_interpolated = 5.262779e+00; cum_chi2_integrated = 6.116536e+00
# [04] rig = 1.811960 [1.71, 1.92]; data = 7.088688e+02; unc = 1.028839e+01; mod = 7.068785e+02; res = -1.934481e-01; mod_int = 7.064843e+02; res_int = -2.317650e-01; cum_chi2_interpolated = 5.300201e+00; cum_chi2_integrated = 6.170251e+00
# [05] rig = 2.031748 [1.92, 2.15]; data = 6.185521e+02; unc = 8.293686e+00; mod = 6.271700e+02; res = +1.039090e+00; mod_int = 6.251452e+02; res_int = +7.949482e-01; cum_chi2_interpolated = 6.379910e+00; cum_chi2_integrated = 6.802193e+00
# [06] rig = 2.271563 [2.15, 2.40]; data = 5.311145e+02; unc = 6.719937e+00; mod = 5.380538e+02; res = +1.032640e+00; mod_int = 5.378331e+02; res_int = +9.997957e-01; cum_chi2_interpolated = 7.446256e+00; cum_chi2_integrated = 7.801785e+00
# [07] rig = 2.531403 [2.40, 2.67]; data = 4.512981e+02; unc = 5.448942e+00; mod = 4.607841e+02; res = +1.740881e+00; mod_int = 4.606065e+02; res_int = +1.708298e+00; cum_chi2_interpolated = 1.047692e+01; cum_chi2_integrated = 1.072007e+01
# [08] rig = 2.816008 [2.67, 2.97]; data = 3.792883e+02; unc = 4.419263e+00; mod = 3.907105e+02; res = +2.584630e+00; mod_int = 3.905155e+02; res_int = +2.540519e+00; cum_chi2_interpolated = 1.715724e+01; cum_chi2_integrated = 1.717430e+01
# [09] rig = 3.125908 [2.97, 3.29]; data = 3.166651e+02; unc = 3.583056e+00; mod = 3.255771e+02; res = +2.487249e+00; mod_int = 3.255142e+02; res_int = +2.469717e+00; cum_chi2_interpolated = 2.334365e+01; cum_chi2_integrated = 2.327380e+01
# [010] rig = 3.460578 [3.29, 3.64]; data = 2.633877e+02; unc = 2.932180e+00; mod = 2.725812e+02; res = +3.135395e+00; mod_int = 2.722943e+02; res_int = +3.037542e+00; cum_chi2_interpolated = 3.317435e+01; cum_chi2_integrated = 3.250046e+01
# [011] rig = 3.825284 [3.64, 4.02]; data = 2.184992e+02; unc = 2.403835e+00; mod = 2.242018e+02; res = +2.372306e+00; mod_int = 2.242049e+02; res_int = +2.373574e+00; cum_chi2_interpolated = 3.880218e+01; cum_chi2_integrated = 3.813431e+01
# [012] rig = 4.220024 [4.02, 4.43]; data = 1.800327e+02; unc = 1.970323e+00; mod = 1.839233e+02; res = +1.974606e+00; mod_int = 1.839257e+02; res_int = +1.975820e+00; cum_chi2_interpolated = 4.270125e+01; cum_chi2_integrated = 4.203818e+01
# [013] rig = 4.649559 [4.43, 4.88]; data = 1.470573e+02; unc = 1.589138e+00; mod = 1.512697e+02; res = +2.650773e+00; mod_int = 1.512219e+02; res_int = +2.620675e+00; cum_chi2_interpolated = 4.972785e+01; cum_chi2_integrated = 4.890612e+01
# [014] rig = 5.119141 [4.88, 5.37]; data = 1.199892e+02; unc = 1.290966e+00; mod = 1.226195e+02; res = +2.037497e+00; mod_int = 1.226476e+02; res_int = +2.059256e+00; cum_chi2_interpolated = 5.387924e+01; cum_chi2_integrated = 5.314665e+01
# [015] rig = 5.628765 [5.37, 5.90]; data = 9.722954e+01; unc = 1.053403e+00; mod = 9.890066e+01; res = +1.586405e+00; mod_int = 9.892259e+01; res_int = +1.607218e+00; cum_chi2_interpolated = 5.639592e+01; cum_chi2_integrated = 5.572980e+01
# [016] rig = 6.178430 [5.90, 6.47]; data = 7.856188e+01; unc = 8.565820e-01; mod = 8.008295e+01; res = +1.775747e+00; mod_int = 8.010000e+01; res_int = +1.795644e+00; cum_chi2_interpolated = 5.954920e+01; cum_chi2_integrated = 5.895414e+01
# [017] rig = 6.772909 [6.47, 7.09]; data = 6.343624e+01; unc = 6.939785e-01; mod = 6.453125e+01; res = +1.577875e+00; mod_int = 6.455502e+01; res_int = +1.612122e+00; cum_chi2_interpolated = 6.203889e+01; cum_chi2_integrated = 6.155308e+01
# [018] rig = 7.417439 [7.09, 7.76]; data = 5.116549e+01; unc = 5.606656e-01; mod = 5.162944e+01; res = +8.275029e-01; mod_int = 5.164897e+01; res_int = +8.623380e-01; cum_chi2_interpolated = 6.272365e+01; cum_chi2_integrated = 6.229670e+01
# [019] rig = 8.112016 [7.76, 8.48]; data = 4.125726e+01; unc = 4.578981e-01; mod = 4.144829e+01; res = +4.171973e-01; mod_int = 4.146343e+01; res_int = +4.502599e-01; cum_chi2_interpolated = 6.289770e+01; cum_chi2_integrated = 6.249944e+01
# [020] rig = 8.861422 [8.48, 9.26]; data = 3.316556e+01; unc = 3.716021e-01; mod = 3.336900e+01; res = +5.474711e-01; mod_int = 3.335502e+01; res_int = +5.098472e-01; cum_chi2_interpolated = 6.319743e+01; cum_chi2_integrated = 6.275938e+01
# [021] rig = 9.670884 [9.26, 10.10]; data = 2.672519e+01; unc = 2.988398e-01; mod = 2.661118e+01; res = -3.815005e-01; mod_int = 2.662462e+01; res_int = -3.365345e-01; cum_chi2_interpolated = 6.334297e+01; cum_chi2_integrated = 6.287264e+01
# [022] rig = 10.540398 [10.10, 11.00]; data = 2.151074e+01; unc = 2.424221e-01; mod = 2.124699e+01; res = -1.087971e+00; mod_int = 2.125736e+01; res_int = -1.045201e+00; cum_chi2_interpolated = 6.452665e+01; cum_chi2_integrated = 6.396508e+01
# [023] rig = 11.958261 [11.00, 13.00]; data = 1.559146e+01; unc = 1.775248e-01; mod = 1.527502e+01; res = -1.782492e+00; mod_int = 1.530201e+01; res_int = -1.630459e+00; cum_chi2_interpolated = 6.770392e+01; cum_chi2_integrated = 6.662348e+01
# [024] rig = 14.690133 [13.00, 16.60]; data = 9.113706e+00; unc = 1.064052e-01; mod = 8.827030e+00; res = -2.694194e+00; mod_int = 8.867564e+00; res_int = -2.313251e+00; cum_chi2_interpolated = 7.496261e+01; cum_chi2_integrated = 7.197461e+01
# [025] rig = 19.454562 [16.60, 22.80]; data = 4.317174e+00; unc = 5.168566e-02; mod = 4.136910e+00; res = -3.487698e+00; mod_int = 4.169324e+00; res_int = -2.860559e+00; cum_chi2_interpolated = 8.712664e+01; cum_chi2_integrated = 8.015740e+01
# [026] rig = 27.636932 [22.80, 33.50]; data = 1.667450e+00; unc = 2.057289e-02; mod = 1.584182e+00; res = -4.047484e+00; mod_int = 1.603203e+00; res_int = -3.122898e+00; cum_chi2_interpolated = 1.035088e+02; cum_chi2_integrated = 8.990989e+01
# [027] rig = 40.308188 [33.50, 48.50]; data = 5.843280e-01; unc = 7.323262e-03; mod = 5.567495e-01; res = -3.765876e+00; mod_int = 5.634067e-01; res_int = -2.856826e+00; cum_chi2_interpolated = 1.176906e+02; cum_chi2_integrated = 9.807135e+01
# [028] rig = 58.141637 [48.50, 69.70]; data = 2.086225e-01; unc = 2.647845e-03; mod = 2.001168e-01; res = -3.212315e+00; mod_int = 2.025754e-01; res_int = -2.283778e+00; cum_chi2_interpolated = 1.280096e+02; cum_chi2_integrated = 1.032870e+02
# [029] rig = 83.486526 [69.70, 100.00]; data = 7.601720e-02; unc = 1.011767e-03; mod = 7.298687e-02; res = -2.995090e+00; mod_int = 7.381427e-02; res_int = -2.177311e+00; cum_chi2_interpolated = 1.369801e+02; cum_chi2_integrated = 1.080277e+02
