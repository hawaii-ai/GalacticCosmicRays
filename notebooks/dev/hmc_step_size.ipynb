# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
"""
RUN 1: hmc-debug-10-06-8482775.out
Running hmc with 500 samples, 100 burn-in steps, and 0 steps between results.
Hyperparameters: step_size=0.0001, max_tree_depth=10, max_energy_diff=1000, unrolled_leapfrog_steps=1, target_accept_prob=0.75, num_adaptation_steps=80.0, and scale=0.01.
Finished in 72 minutes.
Acceptance rate: 0.996. Decrease step_size to increase rate.
energy: mean: -15.654295921325684, std: 1.9506360292434692, min: -23.418447494506836, max: -11.595130920410156
has_divergence: mean: 0.690762996673584, std: 0.4621790051460266, min: False, max: True
is_accepted: mean: 0.9999999403953552, std: 5.960464477539063e-08, min: True, max: True
leapfrogs_taken: mean: 134.74899291992188, std: 118.09896087646484, min: 1, max: 728
log_accept_ratio: mean: -0.05251036956906319, std: 0.06879668682813644, min: -0.526482343673706, max: 0.0
reached_max_depth: mean: 0.0, std: 0.0, min: False, max: False
step_size: mean: 0.0014483523555099964, std: 0.0, min: 0.0014483523555099964, max: 0.0014483523555099964
target_log_prob: mean: -13.166230201721191, std: 1.1738895177841187, min: -17.351720809936523, max: -10.78816032409668
"""

run1 = {
    "step_size": 0.0001,
    "max_tree_depth": 10,
    "max_energy_diff": 1000,
    "unrolled_leapfrog_steps": 1,
    "target_accept_prob": 0.75,
    "num_adaptation_steps": 80.0,
    "scale": 0.01,
    "run_time_minutes": 72,
    "acceptance_rate": 0.996,
    "energy_mean": -15.654295921325684,
    "energy_std": 1.9506360292434692,
    "has_divergence_mean": 0.690762996673584,
    "has_divergence_std": 0.4621790051460266,
    "is_accepted_mean": 0.9999999403953552,
    "is_accepted_std": 5.960464477539063e-08,
    "leapfrogs_taken_mean": 134.74899291992188,
    "leapfrogs_taken_std": 118.09896087646484,
    "log_accept_ratio_mean": -0.05251036956906319,
    "log_accept_ratio_std": 0.06879668682813644,
    "reached_max_depth_mean": 0.0,
    "reached_max_depth_std": 0.0,
    "step_size_mean": 0.0014483523555099964,
    "step_size_std": 0.0,
    "target_log_prob_mean": -13.166230201721191,
    "target_log_prob_std": 1.1738895177841187,
}

# %%
"""
RUN 2: hmc-debug-10-06-8482773.out
Running hmc with 500 samples, 100 burn-in steps, and 0 steps between results.
Hyperparameters: step_size=0.001, max_tree_depth=10, max_energy_diff=1000, unrolled_leapfrog_steps=1, target_accept_prob=0.75, num_adaptation_steps=80.0, and scale=0.01.
Finished in 54 minutes.
Acceptance rate: 0.998. Decrease step_size to increase rate.
energy: mean: -15.625640869140625, std: 1.9682080745697021, min: -24.06258773803711, max: -11.827251434326172
has_divergence: mean: 0.6733466982841492, std: 0.4689892530441284, min: False, max: True
is_accepted: mean: 1.0, std: 0.0, min: True, max: True
leapfrogs_taken: mean: 88.43286895751953, std: 89.23200225830078, min: 2, max: 490
log_accept_ratio: mean: -0.10161246359348297, std: 0.1279246211051941, min: -0.7672265768051147, max: 0.0
reach_max_depth: mean: 0.0, std: 0.0, min: False, max: False
step_size: mean: 0.0019613257609307766, std: 0.0, min: 0.0019613257609307766, max: 0.0019613257609307766
target_log_prob: mean: -13.139705657958984, std: 1.262870192527771, min: -20.251998901367188, max: -10.946250915527344
"""

run2 = {
    "step_size": 0.001,
    "max_tree_depth": 10,
    "max_energy_diff": 1000,
    "unrolled_leapfrog_steps": 1,
    "target_accept_prob": 0.75,
    "num_adaptation_steps": 80.0,
    "scale": 0.01,
    "run_time_minutes": 54,
    "acceptance_rate": 0.998,
    "energy_mean": -15.625640869140625,
    "energy_std": 1.9682080745697021,
    "has_divergence_mean": 0.6733466982841492,
    "has_divergence_std": 0.4689892530441284,
    "is_accepted_mean": 1.0,
    "is_accepted_std": 0.0,
    "leapfrogs_taken_mean": 88.43286895751953,
    "leapfrogs_taken_std": 89.23200225830078,
    "log_accept_ratio_mean": -0.10161246359348297,
    "log_accept_ratio_std": 0.1279246211051941,
    "reached_max_depth_mean": 0.0,
    "reached_max_depth_std": 0.0,
    "step_size_mean": 0.0019613257609307766,
    "step_size_std": 0.0,
    "target_log_prob_mean": -13.139705657958984,
    "target_log_prob_std": 1.262870192527771,
}

# %%
"""
RUN 3: hmc-debug-10-06-8482772.out
Running hmc with 500 samples, 100 burn-in steps, and 0 steps between results.
Hyperparameters: step_size=0.05, max_tree_depth=10, max_energy_diff=1000, unrolled_leapfrog_steps=1, target_accept_prob=0.75, num_adaptation_steps=80.0, and scale=0.01.
Finished in 44 minutes.
Acceptance rate: 0.99. Decrease step_size to increase rate.
energy: mean: -15.628680229187012, std: 2.078390121459961, min: -25.380104064941406, max: -11.986859321594238
has_divergence: mean: 0.7030303478240967, std: 0.45692309737205505, min: False, max: True
is_accepted: mean: 1.0, std: 0.0, min: True, max: True
leapfrogs_taken: mean: 77.5434341430664, std: 81.68889617919922, min: 2, max: 685
log_accept_ratio: mean: -0.1182517260313034, std: 0.14938119053840637, min: -1.0451998710632324, max: 0.0
reach_max_depth: mean: 0.0, std: 0.0, min: False, max: False
step_size: mean: 0.002048105001449585, std: 0.0, min: 0.002048105001449585, max: 0.002048105001449585
target_log_prob: mean: -13.157966613769531, std: 1.4063953161239624, min: -19.464176177978516, max: -10.693184852600098
"""

run3 = {
    "step_size": 0.05,
    "max_tree_depth": 10,
    "max_energy_diff": 1000,
    "unrolled_leapfrog_steps": 1,
    "target_accept_prob": 0.75,
    "num_adaptation_steps": 80.0,
    "scale": 0.01,
    "run_time_minutes": 44,
    "acceptance_rate": 0.99,
    "energy_mean": -15.628680229187012,
    "energy_std": 2.078390121459961,
    "has_divergence_mean": 0.7030303478240967,
    "has_divergence_std": 0.45692309737205505,
    "is_accepted_mean": 1.0,
    "is_accepted_std": 0.0,
    "leapfrogs_taken_mean": 77.5434341430664,
    "leapfrogs_taken_std": 81.68889617919922,
    "log_accept_ratio_mean": -0.1182517260313034,
    "log_accept_ratio_std": 0.14938119053840637,
    "reached_max_depth_mean": 0.0,
    "reached_max_depth_std": 0.0,
    "step_size_mean": 0.002048105001449585,
    "step_size_std": 0.0,
    "target_log_prob_mean": -13.157966613769531,
    "target_log_prob_std": 1.4063953161239624,
}

# %%
"""
RUN 4: hmc-debug-10-06-8566184.out
Running hmc with 500 samples, 100 burn-in steps, and 0 steps between results.
Hyperparameters: step_size=0.01, max_tree_depth=10, max_energy_diff=1000, unrolled_leapfrog_steps=1, target_accept_prob=0.75, num_adaptation_steps=80.0, and scale=0.01.
Finished in 46 minutes.
Acceptance rate: 0.998. Decrease step_size to increase rate.

has_divergence: mean: 0.6873747706413269, std: 0.46356305480003357, min: False, max: True

"""

run4 = {
    "step_size": 0.01,
    "max_tree_depth": 10,
    "max_energy_diff": 1000,
    "unrolled_leapfrog_steps": 1,
    "target_accept_prob": 0.75,
    "num_adaptation_steps": 80.0,
    "scale": 0.01,
    "run_time_minutes": 46,
    "acceptance_rate": 0.998,
    "has_divergence_mean": 0.6873747706413269,
    "has_divergence_std": 0.46356305480003357,
}

# %%
"""
RUN 5: hmc-debug-10-06-8566186.out
Running hmc with 500 samples, 100 burn-in steps, and 0 steps between results.
Hyperparameters: step_size=0.005, max_tree_depth=10, max_energy_diff=1000, unrolled_leapfrog_steps=1, target_accept_prob=0.75, num_adaptation_steps=80.0, and scale=0.01.
Finished in 43 minutes.
Acceptance rate: 0.992. Decrease step_size to increase rate.


has_divergence: mean: 0.6895161271095276, std: 0.4626917243003845, min: False, max: True
"""

run5 = {
    "step_size": 0.005,
    "max_tree_depth": 10,
    "max_energy_diff": 1000,
    "unrolled_leapfrog_steps": 1,
    "target_accept_prob": 0.75,
    "num_adaptation_steps": 80.0,
    "scale": 0.01,
    "run_time_minutes": 43,
    "acceptance_rate": 0.992,
    "has_divergence_mean": 0.6895161271095276,
    "has_divergence_std": 0.4626917243003845,
}

# %%
"""
RUN 6: hmc-debug-10-06-8566188.out
Running hmc with 500 samples, 100 burn-in steps, and 0 steps between results.
Hyperparameters: step_size=0.1, max_tree_depth=10, max_energy_diff=1000, unrolled_leapfrog_steps=1, target_accept_prob=0.75, num_adaptation_steps=80.0, and scale=0.01.

"""
# Out:
# '\nRUN 5: hmc-debug-10-06-8566188.out\nRunning hmc with 500 samples, 100 burn-in steps, and 0 steps between results.\nHyperparameters: step_size=0.1, max_tree_depth=10, max_energy_diff=1000, unrolled_leapfrog_steps=1, target_accept_prob=0.75, num_adaptation_steps=80.0, and scale=0.01.\n\n'

# %% [markdown]
# # Plot

# %%
# Runtime
plt.figure(figsize=(10, 6))
for i, run in enumerate([run1, run2, run3, run4, run5]):
    plt.scatter(run["step_size"], run["run_time_minutes"], label=f"Run {i+1}")
plt.xscale("log")
plt.xlabel("Step Size")
plt.ylabel("Run Time (minutes)")
plt.title("Run Time vs Step Size")
plt.legend()
plt.grid(True)
plt.show()

# %%
# has_divergence_mean with error bars
plt.figure(figsize=(10, 6))
for i, run in enumerate([run1, run2, run3, run4, run5]):
    # plt.errorbar(run["step_size"], run["has_divergence_mean"], yerr=run["has_divergence_std"], label=f"Run {i+1}")
    plt.scatter(run["step_size"], run["has_divergence_mean"], label=f"Run {i+1}", marker='o', s=100)
plt.xscale("log")
plt.xlabel("Step Size")
plt.ylabel("Has Divergence Mean")
plt.title("Has Divergence Mean vs Step Size")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Acceptance rate
plt.figure(figsize=(10, 6))
for i, run in enumerate([run1, run2, run3, run4, run5]):
    plt.scatter(run["step_size"], run["acceptance_rate"], label=f"Run {i+1}", marker='o', s=100)
plt.xscale("log")
plt.xlabel("Step Size")
plt.ylabel("Acceptance Rate")
plt.title("Acceptance Rate vs Step Size")
plt.legend()
plt.grid(True)
plt.show()

# %%
# leapfrogs_taken_mean
plt.figure(figsize=(10, 6))
for i, run in enumerate([run1, run2, run3]):
    plt.errorbar(run["step_size"], run["leapfrogs_taken_mean"], yerr=run["leapfrogs_taken_std"], label=f"Run {i+1}")
    plt.scatter(run["step_size"], run["leapfrogs_taken_mean"], label=f"Run {i+1}")
plt.xscale("log")
plt.xlabel("Step Size")
plt.ylabel("Leapfrogs Taken Mean")
plt.title("Leapfrogs Taken Mean vs Step Size")
plt.legend()
plt.grid(True)
plt.show()
