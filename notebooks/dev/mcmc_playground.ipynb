# %%
import os
os.environ["KERAS_BACKEND"] = "jax"  # Must be specified before loading keras_core
os.environ["JAX_PLATFORM_NAME"] = "cpu"  # CPU is faster for batchsize=1 inference.

import keras_core as kerasjk
import jax
import jax.numpy as jnp
from jax import random, vmap, jit, grad
#assert jax.default_backend() == 'gpu'
import utils
import numpy as np
import pandas as pd
import time
from pathlib import Path
from datetime import datetime
import matplotlib.pyplot as plt
#import elegy # pip install elegy. # Trying to do this with keras core instead.
from tensorflow_probability.substrates import jax as tfp
tfd = tfp.distributions
import tensorflow as tf

# %%
mcmc_or_hmc = 'mcmc' # 'mcmc' or 'hmc'
num_results = 110_000 #110_000 #150000 #500000 # 10k takes 11min. About 1/5 of these accepted? now .97
num_steps_between_results = 0 # Thinning
num_burnin_steps = 100_000 # Number of steps before beginning sampling

# Note: below parameters are only for hmc
num_adaptation_steps = np.floor(.8*num_burnin_steps) #Somewhat smaller than number of burnin
step_size = 1e-4 # 1e-3 (experiment?) # 1e-5 has 0.95 acc rate and moves
max_tree_depth = 10 # Default=10. Smaller results in shorter steps. Larger takes memory.
max_energy_diff = 1000 # Default 1000.0. Divergent samples are those that exceed this.
unrolled_leapfrog_steps = 1 # Default 1. The number of leapfrogs to unroll per tree expansion step

# %%
# Custom normal function with adjustable scale
def custom_normal_fn(scale):
    def normal_fn(x):
        return tfd.Normal(loc=x, scale=scale)
    return normal_fn

class SimpleScaleAdjustedRandomWalkMetropolis(tfp.mcmc.RandomWalkMetropolis):
    def __init__(self, target_log_prob_fn, initial_step_size, num_adaptation_steps, adaptation_rate=0.01, target_accept_prob=0.25, *args, **kwargs):
        super().__init__(target_log_prob_fn, *args, **kwargs)
        self._step_size = initial_step_size
        self.num_adaptation_steps = num_adaptation_steps
        self.adaptation_rate = adaptation_rate
        self.target_accept_prob = target_accept_prob
        self.accept_prob_history = []
        self.adaptation_completed = False

    @property
    def step_size(self):
        return self._step_size

    @step_size.setter
    def step_size(self, value):
        self._step_size = value

    def one_step(self, current_state, previous_kernel_results, seed=None):
        # Update the scale of the normal function based on the current step size
        self.new_state_fn = custom_normal_fn(self.step_size)
        kernel_results = super().one_step(current_state, previous_kernel_results, seed=seed)
        
        # Record the acceptance probability
        accept_prob = tf.math.exp(kernel_results.log_accept_ratio)
        self.accept_prob_history.append(accept_prob)
        
        # Adapt the step size during the first num_adaptation_steps
        if not self.adaptation_completed:
            if len(self.accept_prob_history) >= self.num_adaptation_steps:
                mean_accept_prob = np.mean(self.accept_prob_history)
                if mean_accept_prob > self.target_accept_prob:
                    self._step_size *= (1.0 + self.adaptation_rate)
                else:
                    self._step_size *= (1.0 - self.adaptation_rate)
                    
                # Reset accept_prob_history for the next adaptation phase
                self.accept_prob_history = []
                self.adaptation_completed = True

        return kernel_results

# %%
# Initial step size
initial_step_size = 1.0
target_distribution = tfd.Normal(loc=0., scale=1.)

# Create Custom Random Walk Metropolis kernel
kernel = SimpleScaleAdjustedRandomWalkMetropolis(
    target_log_prob_fn=target_distribution.log_prob,
    initial_step_size=step_size, 
    num_adaptation_steps=num_adaptation_steps, 
    adaptation_rate=0.01, 
    target_accept_prob=0.25
)

def trace_fn(_, pkr):
    return [pkr.log_accept_ratio]

samples, pkr = tfp.mcmc.sample_chain(
        num_results=num_results,
        num_burnin_steps=num_burnin_steps,
        num_steps_between_results=num_steps_between_results,
        kernel=kernel,
        trace_fn=trace_fn,
        current_state=0.0,
        seed=random.PRNGKey(5)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 17
#      14 def trace_fn(_, pkr):
#      15     return [pkr.log_accept_ratio]
# ---> 17 samples, pkr = tfp.mcmc.sample_chain(
#      18         num_results=num_results,
#      19         num_burnin_steps=num_burnin_steps,
#      20         num_steps_between_results=num_steps_between_results,
#      21         kernel=kernel,
#      22         trace_fn=trace_fn,
#      23         current_state=0.0,
#      24         seed=random.PRNGKey(5)
#      25 )
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/mcmc/sample.py:359, in sample_chain(num_results, current_state, previous_kernel_results, kernel, num_burnin_steps, num_steps_between_results, trace_fn, return_final_kernel_results, parallel_iterations, seed, name)
#     352   seed, next_state, current_kernel_results = loop_util.smart_for_loop(
#     353       loop_num_iter=num_steps,
#     354       body_fn=_seeded_one_step,
#     355       initial_loop_vars=list(seed_state_and_results),
#     356       parallel_iterations=parallel_iterations)
#     357   return seed, next_state, current_kernel_results
# --> 359 (_, _, final_kernel_results), (all_states, trace) = loop_util.trace_scan(
#     360     loop_fn=_trace_scan_fn,
#     361     initial_state=(seed, current_state, previous_kernel_results),
#     362     elems=tf.one_hot(
#     363         indices=0,
#     364         depth=num_results,
#     365         on_value=1 + num_burnin_steps,
#     366         off_value=1 + num_steps_between_results,
#     367         dtype=tf.int32),
#     368     # pylint: disable=g-long-lambda
#     369     trace_fn=lambda seed_state_and_results: (
#     370         seed_state_and_results[1], trace_fn(*seed_state_and_results[1:])),
#     371     # pylint: enable=g-long-lambda
#     372     parallel_iterations=parallel_iterations)
#     374 if return_final_kernel_results:
#     375   return CheckpointableStatesAndTrace(
#     376       all_states=all_states,
#     377       trace=trace,
#     378       final_kernel_results=final_kernel_results)
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/internal/loop_util.py:222, in trace_scan(loop_fn, initial_state, elems, trace_fn, trace_criterion_fn, static_trace_allocation_size, condition_fn, parallel_iterations, name)
#     214   trace_arrays, num_steps_traced = ps.cond(
#     215       trace_criterion_fn(state) if trace_criterion_fn else True,
#     216       lambda: (trace_one_step(num_steps_traced, trace_arrays, state),  # pylint: disable=g-long-lambda
#     217                num_steps_traced + 1),
#     218       lambda: (trace_arrays, num_steps_traced))
#     220   return i + 1, state, num_steps_traced, trace_arrays
# --> 222 _, final_state, _, trace_arrays = tf.while_loop(
#     223     cond=condition_fn if condition_fn is not None else lambda *_: True,
#     224     body=_body,
#     225     loop_vars=(0, initial_state, 0, trace_arrays),
#     226     maximum_iterations=length,
#     227     parallel_iterations=parallel_iterations)
#     229 # unflatten
#     230 stacked_trace = tf.nest.pack_sequence_as(
#     231     initial_trace, [ta.stack() for ta in trace_arrays],
#     232     expand_composites=True)
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/python/internal/backend/jax/_utils.py:62, in copy_docstring.<locals>.wrap(***failed resolving arguments***)
#      59 @wrapt.decorator
#      60 def wrap(wrapped, instance, args, kwargs):
#      61   del instance, wrapped
# ---> 62   return new_fn(*args, **kwargs)
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/python/internal/backend/jax/control_flow.py:102, in _while_loop_jax(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      99       args = pack_body(body(*args))
#     100     return args, ()
# --> 102   loop_vars, _ = lax.scan(
#     103       override_body_fn, loop_vars, xs=None, length=maximum_iterations)
#     104   return loop_vars
#     105 else:
#
#     [... skipping hidden 9 frame]
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/python/internal/backend/jax/control_flow.py:99, in _while_loop_jax.<locals>.override_body_fn(args, _)
#      96   args = lax.cond(c, args, lambda args: pack_body(body(*args)), args,
#      97                   lambda args: args)
#      98 elif sc:
# ---> 99   args = pack_body(body(*args))
#     100 return args, ()
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/internal/loop_util.py:212, in trace_scan.<locals>._body(i, state, num_steps_traced, trace_arrays)
#     210 def _body(i, state, num_steps_traced, trace_arrays):
#     211   elem = elems_array.read(i)
# --> 212   state = loop_fn(state, elem)
#     214   trace_arrays, num_steps_traced = ps.cond(
#     215       trace_criterion_fn(state) if trace_criterion_fn else True,
#     216       lambda: (trace_one_step(num_steps_traced, trace_arrays, state),  # pylint: disable=g-long-lambda
#     217                num_steps_traced + 1),
#     218       lambda: (trace_arrays, num_steps_traced))
#     220   return i + 1, state, num_steps_traced, trace_arrays
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/mcmc/sample.py:352, in sample_chain.<locals>._trace_scan_fn(seed_state_and_results, num_steps)
#     351 def _trace_scan_fn(seed_state_and_results, num_steps):
# --> 352   seed, next_state, current_kernel_results = loop_util.smart_for_loop(
#     353       loop_num_iter=num_steps,
#     354       body_fn=_seeded_one_step,
#     355       initial_loop_vars=list(seed_state_and_results),
#     356       parallel_iterations=parallel_iterations)
#     357   return seed, next_state, current_kernel_results
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/internal/loop_util.py:97, in smart_for_loop(loop_num_iter, body_fn, initial_loop_vars, parallel_iterations, unroll_threshold, name)
#      87 if (loop_num_iter_ is None
#      88     or tf.executing_eagerly()
#      89     # large values for loop_num_iter_ will cause ridiculously slow
#    (...)
#      94   # Cast to int32 to run the comparison against i in host memory,
#      95   # where while/LoopCond needs it.
#      96   loop_num_iter = tf.cast(loop_num_iter, dtype=tf.int32)
# ---> 97   return tf.while_loop(
#      98       cond=lambda i, *args: i < loop_num_iter,
#      99       body=lambda i, *args: [i + 1] + list(body_fn(*args)),
#     100       loop_vars=[np.int32(0)] + initial_loop_vars,
#     101       parallel_iterations=parallel_iterations
#     102   )[1:]
#     103 result = initial_loop_vars
#     104 for _ in range(loop_num_iter_):
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/python/internal/backend/jax/_utils.py:62, in copy_docstring.<locals>.wrap(***failed resolving arguments***)
#      59 @wrapt.decorator
#      60 def wrap(wrapped, instance, args, kwargs):
#      61   del instance, wrapped
# ---> 62   return new_fn(*args, **kwargs)
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/python/internal/backend/jax/control_flow.py:90, in _while_loop_jax(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      88   def override_cond_fn(args):
#      89     return cond(*args)
# ---> 90   return lax.while_loop(override_cond_fn, override_body_fn, loop_vars)
#      91 elif back_prop:
#      92   def override_body_fn(args, _):
#
#     [... skipping hidden 9 frame]
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/python/internal/backend/jax/control_flow.py:87, in _while_loop_jax.<locals>.override_body_fn(args)
#      86 def override_body_fn(args):
# ---> 87   return pack_body(body(*args))
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/internal/loop_util.py:99, in smart_for_loop.<locals>.<lambda>(i, *args)
#      87 if (loop_num_iter_ is None
#      88     or tf.executing_eagerly()
#      89     # large values for loop_num_iter_ will cause ridiculously slow
#    (...)
#      94   # Cast to int32 to run the comparison against i in host memory,
#      95   # where while/LoopCond needs it.
#      96   loop_num_iter = tf.cast(loop_num_iter, dtype=tf.int32)
#      97   return tf.while_loop(
#      98       cond=lambda i, *args: i < loop_num_iter,
# ---> 99       body=lambda i, *args: [i + 1] + list(body_fn(*args)),
#     100       loop_vars=[np.int32(0)] + initial_loop_vars,
#     101       parallel_iterations=parallel_iterations
#     102   )[1:]
#     103 result = initial_loop_vars
#     104 for _ in range(loop_num_iter_):
#
# File ~/sadow_koastore/personal/linneamw/anaconda3/envs/gcr/lib/python3.9/site-packages/tensorflow_probability/substrates/jax/mcmc/sample.py:349, in sample_chain.<locals>._seeded_one_step(seed, *state_and_results)
#     345 step_seed, passalong_seed = (
#     346     samplers.split_seed(seed) if is_seeded else (None, seed))
#     347 one_step_kwargs = dict(seed=step_seed) if is_seeded else {}
#     348 return [passalong_seed] + list(
# --> 349     kernel.one_step(*state_and_results, **one_step_kwargs))
#
# Cell In[16], line 27, in SimpleScaleAdjustedRandomWalkMetropolis.one_step(self, current_state, previous_kernel_results, seed)
#      25 def one_step(self, current_state, previous_kernel_results, seed=None):
#      26     # Update the scale of the normal function based on the current step size
# ---> 27     self.new_state_fn = custom_normal_fn(self.step_size)
#      28     kernel_results = super().one_step(current_state, previous_kernel_results, seed=seed)
#      30     # Record the acceptance probability
#
# AttributeError: can't set attribute
